# %%
import pandas as pd
import json

# %%
with open(r"D:\盐野义\月报\人群画像\美白丸竞店\美白丸购买竞店省年城.json","r",encoding="UTF-8") as f1:
    competition1 = json.load(f1)
with open(r"D:\盐野义\月报\人群画像\美白丸竞店\美白丸购买竞店策略.json","r",encoding="UTF-8") as f2:
    competition2 = json.load(f2)

# %%
data = {"rivalShop2":{},"rivalShop1":{},"selfShop":{}}

# %%
competition1
# Out:
# {'traceId': '21082ced17222480912031182e124f',
#  'code': 0,
#  'data': {'rivalShop2': {'gender': [{'statDate': 1722096000000,
#      'attributeValue': 'F',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.7853725222146275},
#     {'statDate': 1722096000000,
#      'attributeValue': 'M',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.21462747778537253}],
#    'province': [{'statDate': 1722096000000,
#      'attributeValue': '江苏省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.1255783212161269},
#     {'statDate': 1722096000000,
#      'attributeValue': '上海',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.12359550561797752},
#     {'statDate': 1722096000000,
#      'attributeValue': '广东省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.10971579643093192},
#     {'statDate': 1722096000000,
#      'attributeValue': '浙江省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.10707204230006609},
#     {'statDate': 1722096000000,
#      'attributeValue': '北京',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.07402511566424323},
#     {'statDate': 1722096000000,
#      'attributeValue': '山东省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.056179775280898875},
#     {'statDate': 1722096000000,
#      'attributeValue': '福建省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0449438202247191},
#     {'statDate': 1722096000000,
#      'attributeValue': '湖北省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.04130865829477859},
#     {'statDate': 1722096000000,
#      'attributeValue': '四川省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0380039656311963},
#     {'statDate': 1722096000000,
#      'attributeValue': '辽宁省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.036351619299405155}],
#    'age': [{'statDate': 1722096000000,
#      'attributeValue': '18-24岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.10828877005347594},
#     {'statDate': 1722096000000,
#      'attributeValue': '25-29岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.19919786096256684},
#     {'statDate': 1722096000000,
#      'attributeValue': '30-34岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.2122326203208556},
#     {'statDate': 1722096000000,
#      'attributeValue': '35-39岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.18081550802139038},
#     {'statDate': 1722096000000,
#      'attributeValue': '40-49岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.21758021390374332},
#     {'statDate': 1722096000000,
#      'attributeValue': '50岁及以上',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.07787433155080214},
#     {'statDate': 1722096000000,
#      'attributeValue': '未知',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.004010695187165776}]},
#   'rivalShop1': {'gender': [{'statDate': 1722096000000,
#      'attributeValue': 'F',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.8469945355191257},
#     {'statDate': 1722096000000,
#      'attributeValue': 'M',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.15300546448087432}],
#    'province': [{'statDate': 1722096000000,
#      'attributeValue': '云南省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0893909626719057},
#     {'statDate': 1722096000000,
#      'attributeValue': '天津',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0893909626719057},
#     {'statDate': 1722096000000,
#      'attributeValue': '江西省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0893909626719057},
#     {'statDate': 1722096000000,
#      'attributeValue': '陕西省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.0893909626719057},
#     {'statDate': 1722096000000,
#      'attributeValue': '江苏省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.07956777996070727},
#     {'statDate': 1722096000000,
#      'attributeValue': '山西省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.06679764243614932},
#     {'statDate': 1722096000000,
#      'attributeValue': '贵州省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.06679764243614932},
#     {'statDate': 1722096000000,
#      'attributeValue': '广东省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.05992141453831041},
#     {'statDate': 1722096000000,
#      'attributeValue': '广西壮族自治区',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.047151277013752456},
#     {'statDate': 1722096000000,
#      'attributeValue': '河北省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.047151277013752456}],
#    'age': [{'statDate': 1722096000000,
#      'attributeValue': '18-24岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.14418604651162792},
#     {'statDate': 1722096000000,
#      'attributeValue': '25-29岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.14186046511627906},
#     {'statDate': 1722096000000,
#      'attributeValue': '30-34岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.2},
#     {'statDate': 1722096000000,
#      'attributeValue': '35-39岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.14883720930232558},
#     {'statDate': 1722096000000,
#      'attributeValue': '40-49岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.14186046511627906},
#     {'statDate': 1722096000000,
#      'attributeValue': '50岁及以上',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.06511627906976744},
#     {'statDate': 1722096000000,
#      'attributeValue': '未知',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.15813953488372093}]},
#   'selfShop': {'gender': [{'statDate': 1722096000000,
#      'attributeValue': 'F',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.37926727726894255},
#     {'statDate': 1722096000000,
#      'attributeValue': 'M',
#      'attributeName': 'gender',
#      'payByrCntRatio': 0.6207327227310575}],
#    'province': [{'statDate': 1722096000000,
#      'attributeValue': '广东省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.14152473641524738},
#     {'statDate': 1722096000000,
#      'attributeValue': '浙江省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.09367396593673966},
#     {'statDate': 1722096000000,
#      'attributeValue': '江苏省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.08860502838605028},
#     {'statDate': 1722096000000,
#      'attributeValue': '上海',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.08414436334144364},
#     {'statDate': 1722096000000,
#      'attributeValue': '北京',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.06914030819140309},
#     {'statDate': 1722096000000,
#      'attributeValue': '四川省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.05291970802919708},
#     {'statDate': 1722096000000,
#      'attributeValue': '山东省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.04339010543390105},
#     {'statDate': 1722096000000,
#      'attributeValue': '湖北省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.041768045417680456},
#     {'statDate': 1722096000000,
#      'attributeValue': '福建省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.03527980535279805},
#     {'statDate': 1722096000000,
#      'attributeValue': '湖南省',
#      'attributeName': 'province',
#      'payByrCntRatio': 0.033657745336577456}],
#    'age': [{'statDate': 1722096000000,
#      'attributeValue': '18-24岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.25},
#     {'statDate': 1722096000000,
#      'attributeValue': '25-29岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.24631751227495907},
#     {'statDate': 1722096000000,
#      'attributeValue': '30-34岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.1712356792144026},
#     {'statDate': 1722096000000,
#      'attributeValue': '35-39岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.1239770867430442},
#     {'statDate': 1722096000000,
#      'attributeValue': '40-49岁',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.11292962356792144},
#     {'statDate': 1722096000000,
#      'attributeValue': '50岁及以上',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.06076104746317512},
#     {'statDate': 1722096000000,
#      'attributeValue': '未知',
#      'attributeName': 'age',
#      'payByrCntRatio': 0.03477905073649754}]}},
#  'message': '操作成功'}

# %%
for shop in ["rivalShop2","rivalShop1","selfShop"]:
    for gender in competition1["data"][shop]["gender"]:
        data[shop][gender["attributeValue"]]=gender["payByrCntRatio"]
    for province in competition1["data"][shop]["province"]:
        data[shop][province["attributeValue"]]=province["payByrCntRatio"]
    for age in competition1["data"][shop]["age"]:
        data[shop][age["attributeValue"]]=age["payByrCntRatio"]
    for groups in competition2["data"][shop]:
        data[shop][groups["crowdId"]]=groups["payByrCntRatio"]

# %%
df = pd.DataFrame(data)
df.fillna(0,inplace=True)

# %%
df.to_excel("D:/盐野义/月报/人群画像/美白丸竞店购买人群画像.xlsx")
