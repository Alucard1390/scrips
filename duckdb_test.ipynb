# %%
import duckdb

# %%
rel = duckdb.sql("SELECT * FROM read_xlsx('D:/pbtest/item/希纳露4-5月_20250606.xlsx');")

# %%
rel.columns
# Out:
# ['统计日期',
#  '店铺名称',
#  '商品ID',
#  '商品名称',
#  '商品状态',
#  '一级类目名称',
#  '二级类目名称',
#  '叶子类目名称',
#  '主图整体点击率',
#  '描述相符（近180天）',
#  '商品访客数',
#  '下单买家数',
#  '下单件数',
#  '下单金额',
#  '下单转化率',
#  '支付金额',
#  '成功退款金额',
#  '支付件数',
#  '支付买家数',
#  '支付转化率',
#  '加购件数',
#  '支付老买家数',
#  '老买家支付金额',
#  '加购人数',
#  '商品收藏人数',
#  '商品浏览量',
#  '客单价',
#  'UV价值',
#  '平均停留时长（秒）',
#  '商品详情页跳出率',
#  '搜索引导访客数',
#  '无线端商品访客数',
#  '无线端商品浏览量',
#  '无线端商品详情页跳出率',
#  '无线端平均停留时长（秒）',
#  '无线端加购件数',
#  '无线端商品收藏人数',
#  '无线端支付金额',
#  '无线端支付件数',
#  '无线端支付买家数',
#  '无线端客单价',
#  '无线端支付转化率',
#  'PC端曝光量',
#  'PC端点击次数',
#  'PC端商品详情页跳出率',
#  'PC端平均停留时长（秒）',
#  'PC端商品访客数',
#  'PC端商品浏览量',
#  'PC端加购件数',
#  'PC端商品收藏人数',
#  'PC端支付金额',
#  'PC端支付件数',
#  'PC端支付买家数',
#  'PC端客单价',
#  'PC端支付转化率']

# %%
duckdb.sql("select * from rel where 统计日期>='2025-05-01' order by 商品ID asc limit 3")
# Out:
# ┌────────────┬──────────────────────┬──────────────┬───────────────────────────────────────────────────────────┬──────────┬──────────────────┬──────────────┬──────────────────┬────────────────┬─────────────────────┬────────────┬────────────┬──────────┬───────────┬────────────┬───────────┬──────────────┬──────────┬────────────┬────────────┬──────────┬──────────────┬────────────────┬──────────┬──────────────┬────────────┬─────────┬─────────┬────────────────────┬──────────────────┬────────────────┬──────────────────┬──────────────────┬────────────────────────┬──────────────────────────┬────────────────┬────────────────────┬────────────────┬────────────────┬──────────────────┬──────────────┬──────────────────┬────────────┬──────────────┬──────────────────────┬────────────────────────┬────────────────┬────────────────┬──────────────┬──────────────────┬──────────────┬──────────────┬────────────────┬────────────┬────────────────┐
# ...
